# %% [markdown]
# ### Notebooks
#
# - **01_delivery_time_analysis.ipynb**
#   Analysis of delivery time distribution for delivered orders, focusing on median and interquartile range (IQR).
#
# - **02_on_time_vs_late.ipynb** *(coming next)*
#   Comparison between actual and estimated delivery dates.
#
# - **03_delivery_by_location_or_seller.ipynb** *(planned)*
#   Exploration of delivery performance across cities and sellers.
